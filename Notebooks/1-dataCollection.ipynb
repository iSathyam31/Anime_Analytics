# %% [markdown]
# ### Importing Libraries

# %%
import requests
import pandas as pd
import time
import os
import json

# %% [markdown]
# ### Collect data from myanimelist.net API

# %% [markdown]
# #### Test with one anime first to see what features are available

# %%
# query for anime
response_query = requests.get("https://api.myanimelist.net/v2/anime?q=one&limit=4", 
                        headers={'X-MAL-CLIENT-ID': '34e749b42846abadb1be2d886253fb7d'})
print("Response:", response_query.status_code)
# Out:
# Response: 200

# %%
response_query.json()
# Out:
# {'data': [{'node': {'id': 21,
#     'title': 'One Piece',
#     'main_picture': {'medium': 'https://cdn.myanimelist.net/images/anime/1244/138851.webp',
#      'large': 'https://cdn.myanimelist.net/images/anime/1244/138851l.webp'}}},
#   {'node': {'id': 459,
#     'title': 'One Piece Movie 01',
#     'main_picture': {'medium': 'https://cdn.myanimelist.net/images/anime/1770/97704.jpg',
#      'large': 'https://cdn.myanimelist.net/images/anime/1770/97704l.jpg'}}},
#   {'node': {'id': 12859,
#     'title': 'One Piece Film: Z',
#     'main_picture': {'medium': 'https://cdn.myanimelist.net/images/anime/6/44297.jpg',
#      'large': 'https://cdn.myanimelist.net/images/anime/6/44297l.jpg'}}},
#   {'node': {'id': 31772,
#     'title': 'One Punch Man Specials',
#     'main_picture': {'medium': 'https://cdn.myanimelist.net/images/anime/1452/97840.jpg',
#      'large': 'https://cdn.myanimelist.net/images/anime/1452/97840l.jpg'}}}],
#  'paging': {'next': 'https://api.myanimelist.net/v2/anime?offset=4&q=one&limit=4'}}

# %%
# extract anime id and title, did use the anime picture
anime = response_query.json()['data'][0]['node']
anime_id = anime['id']
anime
# Out:
# {'id': 21,
#  'title': 'One Piece',
#  'main_picture': {'medium': 'https://cdn.myanimelist.net/images/anime/1244/138851.webp',
#   'large': 'https://cdn.myanimelist.net/images/anime/1244/138851l.webp'}}

# %%
# anime details
response_details = requests.get(f'https://api.myanimelist.net/v2/anime/30230?fields=id,title,main_picture,alternative_titles,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,pictures,background,related_anime,related_manga,recommendations,studios,statistics',
                        headers={'X-MAL-CLIENT-ID': '34e749b42846abadb1be2d886253fb7d'})
print("Response:", response_details.status_code)
# Out:
# Response: 200

# %%
print("Features Avaiable:")
print("-----")
for feature in response_details.json().keys():
    print(feature)
# Out:
# Features Avaiable:
# -----
# id
# title
# main_picture
# alternative_titles
# start_date
# end_date
# synopsis
# mean
# rank
# popularity
# num_list_users
# num_scoring_users
# nsfw
# created_at
# updated_at
# media_type
# status
# genres
# num_episodes
# start_season
# broadcast
# source
# average_episode_duration
# rating
# pictures
# background
# related_anime
# related_manga
# recommendations
# studios
# statistics

# %% [markdown]
# **From the above list of Features, we will be selecting the following features**:
#
# - id
# - title
# - start_date
# - end_date
# - synopsis
# - mean
# - rank
# - popularity
# - num_list_users
# - num_scoring_users
# - nsfw
# - created_at
# - updated_at
# - media_type
# - status
# - genres
# - num_episodes
# - start_season
# - broadcast
# - source
# - average_episode_duration
# - rating
# - background
# - studios
# - statistics

# %% [markdown]
# ### Get top ranked animes in various categories

# %%
ranking_categories = [
    'all',
    'airing',
    'tv',
    'ova',
    'movie',
    'special',
    'bypopularity',
    'favorite'
]

# %%
def create_ranking_csv(ranking_type):
    # Create the directory if it doesn't exist
    os.makedirs('dataset/rankings', exist_ok=True)
    try:
        # getting the top 500 for each category ranking
        response_ranking = requests.get(f'https://api.myanimelist.net/v2/anime/ranking?ranking_type={ranking_type}&limit=500',
                                       headers={'X-MAL-CLIENT-ID': '34e749b42846abadb1be2d886253fb7d'})
        
        # Print full response for debugging
        print(f'Response status ({ranking_type}): {response_ranking.status_code}')
        print('Response content:', response_ranking.text)
        
        # Check if response is successful
        response_ranking.raise_for_status()
        
        # Try parsing JSON with error handling
        try:
            ranking_data = response_ranking.json()
        except json.JSONDecodeError as e:
            print(f"JSON Decode Error: {e}")
            print("Response content:", response_ranking.text)
            return

        # querying anime details for each anime in the ranking list
        anime_ranking_list = []
        rank = 0

        for anime in ranking_data['data']:
            rank += 1
            anime_id = anime['node']['id']

            try:
                # query for anime details
                response_details = requests.get(
                    f'https://api.myanimelist.net/v2/anime/{anime_id}?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics',
                    headers={'X-MAL-CLIENT-ID': '34e749b42846abadb1be2d886253fb7d'}
                )
                
                # Check if details response is successful
                response_details.raise_for_status()
                
                anime_details = response_details.json()
                anime_details[f'{ranking_type}_ranking'] = rank    # adding {ranking_type}_ranking feature
                anime_ranking_list.append(anime_details)
                
            except requests.RequestException as e:
                print(f"Error fetching details for anime {anime_id}: {e}")
                continue

        # convert into a dataframe and store as csv file
        if anime_ranking_list:
            df = pd.DataFrame(anime_ranking_list)
            df.to_csv(f'dataset/rankings/ranking_{ranking_type}.csv', index=False)
            print('csv created!')
        else:
            print(f"No anime details collected for {ranking_type}")

    except requests.RequestException as e:
        print(f"Request Error for {ranking_type}: {e}")

# %%
for ranking_type in ranking_categories:
    create_ranking_csv(ranking_type)
    
    # add delay for fetching the next api
    time.sleep(200)
# Out:
# Response status (all): 200
# Response content: {"data":[{"node":{"id":52991,"title":"Sousou no Frieren","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1015\/138006.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1015\/138006l.webp"}},"ranking":{"rank":1}},{"node":{"id":5114,"title":"Fullmetal Alchemist: Brotherhood","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1208\/94745.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1208\/94745l.jpg"}},"ranking":{"rank":2}},{"node":{"id":60022,"title":"One Piece Fan Letter","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1455\/146229.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1455\/146229l.jpg"}},"ranking":{"rank":3}},{"node":{"id":9253,"title":"Steins;Gate","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1935\/127974.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1935\/127974l.jpg"}},"ranking":{"rank":4}},{"node":{"id":38524,"title":"Shingeki no Kyojin Season 3 Part 2","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1517\/100633.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1517\/100633l.webp"}},"ranking":{"rank":5}},{"node":{"id":28977,"title":"Gintama\u00b0","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/3\/72078.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/3\/72078l.webp"}},"ranking":{"rank":6}},{"node":{"id":39486,"title":"Gintama: The Final","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1245\/116760.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1245\/116760l.jpg"}},"ranking":{"rank":7}},{"node":{"id":9969,"title":"Gintama'","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/4\/50361.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/4\/50361l.webp"}},"ranking":{"rank":8}},{"node":{"id":11061,"title":"Hunter x Hunter (2011)","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1337\/99013.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1337\/99013l.jpg"}},"ranking":{"rank":9}},{"node":{"id":15417,"title":"Gintama': Enchousen","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1452\/123686.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1452\/123686l.webp"}},"ranking":{"rank":10}},{"node":{"id":41467,"title":"Bleach: Sennen Kessen-hen","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/
main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1208\/94745.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1208\/94745l.jpg"}},"ranking":{"rank":2}},{"node":{"id":11061,"title":"Hunter x Hunter (2011)","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1337\/99013.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1337\/99013l.jpg"}},"ranking":{"rank":3}},{"node":{"id":9253,"title":"Steins;Gate","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1935\/127974.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1935\/127974l.jpg"}},"ranking":{"rank":4}},{"node":{"id":1535,"title":"Death Note","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1079\/138100.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1079\/138100l.webp"}},"ranking":{"rank":5}},{"node":{"id":16498,"title":"Shingeki no Kyojin","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/10\/47347.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/10\/47347l.webp"}},"ranking":{"rank":6}},{"node":{"id":1735,"title":"Naruto: Shippuuden","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1565\/111305.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1565\/111305l.webp"}},"ranking":{"rank":7}},{"node":{"id":1575,"title":"Code Geass: Hangyaku no Lelouch","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1032\/135088.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1032\/135088l.jpg"}},"ranking":{"rank":8}},{"node":{"id":30,"title":"Shinseiki Evangelion","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1314\/108941.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1314\/108941l.jpg"}},"ranking":{"rank":9}},{"node":{"id":40748,"title":"Jujutsu Kaisen","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1171\/109222.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1171\/109222l.jpg"}},"ranking":{"rank":10}},{"node":{"id":38000,"title":"Kimetsu no Yaiba","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1286\/99889.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1286\/99889l.jpg"}},"ranking":{"rank":11}},{"node":{"id":32281,"title":"Kimi no Na wa.","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/5\/87048.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/5\/87048l.jpg"}},"ranking":{"rank":12}},{"node":{"id":28851,"title":"Koe no Katachi","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1122\/96435.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1122\/96435l.jpg"}},"ranking":{"rank":13}},{"node":{"id":23273,"title":"Shigatsu wa Kimi no Uso","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1405\/143284.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1405\/143284l.webp"}},"ranking":{"rank":14}},{"node":{"id":1,"title":"Cowboy Bebop","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/4\/19644.jpg","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/4\/19644l.jpg"}},"ranking":{"rank":15}},{"node":{"id":20,"title":"Naruto","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/1141\/142503.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/1141\/142503l.webp"}},"ranking":{"rank":16}},{"node":{"id":2001,"title":"Tengen Toppa Gurren Lagann","main_picture":{"medium":"https:\/\/cdn.myanimelist.net\/images\/anime\/4\/5123.webp","large":"https:\/\/cdn.myanimelist.net\/images\/anime\/4\/5123l.webp"}},"ranking":{"rank ...
# Error fetching details for anime 22135: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/22135?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 6: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/6?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 48316: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/48316?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 10721: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/10721?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 3457: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/3457?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 51179: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/51179?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 50631: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/50631?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 11759: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/11759?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 50425: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/50425?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# csv created!

# %% [markdown]
# ### Get animes from 2000-2024

# %%
response = requests.get('https://api.myanimelist.net/v2/anime/season/2017/summer?limit=4',
                            headers={'X-MAL-CLIENT-ID': '34e749b42846abadb1be2d886253fb7d'})

# %%
response.json()['data'][0]
# Out:
# {'node': {'id': 35247,
#   'title': 'Owarimonogatari 2nd Season',
#   'main_picture': {'medium': 'https://cdn.myanimelist.net/images/anime/6/87322.webp',
#    'large': 'https://cdn.myanimelist.net/images/anime/6/87322l.webp'}}}

# %%
'''
Season name     Months
winter:         January, February, March
spring:         April, May, June
summer          July, August, September
fall            October, November, December
'''
seasons = [
    "winter",
    "spring",
    "summer",
    "fall"
]

# %%
def get_anime_season(year, season, anime_list):
    try:
        # Fetch animes from a particular season of a particular year
        response = requests.get(
            f'https://api.myanimelist.net/v2/anime/season/{year}/{season}?limit=100',
            headers={'X-MAL-CLIENT-ID': '34e749b42846abadb1be2d886253fb7d'}
        )
        
        # Check if the request was successful
        response.raise_for_status()
        
        # Parse JSON response
        try:
            season_data = response.json()
        except json.JSONDecodeError as e:
            print(f"JSON Decode Error for {year}/{season}: {e}")
            print("Response content:", response.text)
            return anime_list

        # Iterate through anime in the season
        for anime in season_data.get('data', []):
            try:
                anime_id = anime['node']['id']

                # Query for detailed anime information
                response_details = requests.get(
                    f'https://api.myanimelist.net/v2/anime/{anime_id}?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics',
                    headers={'X-MAL-CLIENT-ID': '34e749b42846abadb1be2d886253fb7d'}
                )
                
                # Check if details request was successful
                response_details.raise_for_status()
                
                # Parse anime details
                anime_details = response_details.json()
                
                # Add season and year information
                anime_details['season'] = season
                anime_details['year'] = year
                
                # Add to list
                anime_list.append(anime_details)
                
            except requests.RequestException as detail_err:
                print(f"Error fetching details for anime {anime_id} in {year}/{season}: {detail_err}")
                continue

        print(f'Successfully processed {year}/{season}')
        
    except requests.RequestException as e:
        print(f"Request Error for {year}/{season}: {e}")
    
    return anime_list

# %%
anime_list = []

# %%
for year in range(2000, 2024):
    for season in seasons:
        # fetch api for {year} & {season}
        anime_list = get_anime_season(year, season, anime_list)

        # add delay for fetching the next api
        time.sleep(60)
# Out:
# Successfully processed 2000/winter
# Error fetching details for anime 189 in 2000/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/189?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 2617 in 2000/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/2617?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2000/spring
# Successfully processed 2000/summer
# Error fetching details for anime 4459 in 2000/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/4459?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 2538 in 2000/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/2538?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2000/fall
# Error fetching details for anime 2566 in 2001/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/2566?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2001/winter
# Error fetching details for anime 24647 in 2001/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/24647?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2001/spring
# Error fetching details for anime 1126 in 2001/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/1126?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2001/summer
# Error fetching details for anime 22485 in 2001/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/22485?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2001/fall
# Error fetching details for anime 683 in 2002/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/683?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2002/winter
# Error fetching details for anime 154 in 2002/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/154?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2002/spring
# Error fetching details for anime 31494 in 2002/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/31494?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2002/summer
# Error fetching details for anime 341 in 2002/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/341?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2002/fall
# Error fetching details for anime 153 in 2003/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/153?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2003/winter
# Error fetching details for anime 5071 in 2003/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/5071?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2003/spring
# Error fetching details for anime 235 in 2003/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/235?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 301 in 2003/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/301?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2003/summer
# Successfully processed 2003/fall
# Error fetching details for anime 2363 in 2004/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/2363?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 222 in 2004/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/222?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2004/winter
# Successfully processed 2004/spring
# Error fetching details for anime 1377 in 2004/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/1377?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 3638 in 2004/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/3638?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2004/summer
# Successfully processed 2004/fall
# Request Error for 2005/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/season/2005/winter?limit=100
# Successfully processed 2005/spring
# Error fetching details for anime 251 in 2005/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/251?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 488 in 2005/summer: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/488?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2005/summer
# Successfully processed 2005/fall
# Error fetching details for anime 858 in 2006/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/858?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 4823 in 2006/winter: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/4823?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2006/winter
# Error fetching details for anime 3724 in 2006/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/3724?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 39514 in 2006/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/39514?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2006/spring
# Successfully processed 2006/summer
# Error fetching details for anime 1594 in 2006/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/1594?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 2154 in 2006/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/2154?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2006/fall
# Successfully processed 2007/winter
# Request Error for 2007/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/season/2007/spring?limit=100
# Successfully processed 2007/summer
# Error fetching details for anime 3991 in 2007/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/3991?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 3256 in 2007/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/3256?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2007/fall
# Successfully processed 2008/winter
# Request Error for 2008/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/season/
spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/55313?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Error fetching details for anime 55756 in 2023/spring: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/55756?fields=id,title,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,background,studios,statistics
# Successfully processed 2023/spring
# Successfully processed 2023/summer
# Request Error for 2023/fall: 504 Server Error: Gateway Timeout for url: https://api.myanimelist.net/v2/anime/season/2023/fall?limit=100

# %%
anime_df = pd.DataFrame(anime_list)
anime_df.to_csv('dataset/anime.csv', index=False)

# %%
print(f"Total anime collected: {len(anime_df)}")
print(anime_df.head())
# Out:
# Total anime collected: 7819
#      id                                             title  \
# 0    21                                         One Piece
# 1  3665                Ginga Eiyuu Densetsu Gaiden (1999)
# 2  3545  Kochira Katsushikaku Kameari Kouenmae Hashutsujo
# 3   136                                   Hunter x Hunter
# 4   245                             Great Teacher Onizuka
#
#                                         main_picture  start_date  \
# 0  {'medium': 'https://cdn.myanimelist.net/images...  1999-10-20
# 1  {'medium': 'https://cdn.myanimelist.net/images...  1999-12-24
# 2  {'medium': 'https://cdn.myanimelist.net/images...  1996-06-16
# 3  {'medium': 'https://cdn.myanimelist.net/images...  1999-10-16
# 4  {'medium': 'https://cdn.myanimelist.net/images...  1999-06-30
#
#                                             synopsis  mean    rank  \
# 0  Barely surviving in a barrel after passing thr...  8.72    54.0
# 1  Ginga Eiyuu Densetsu Gaiden (1999) is the seco...  8.06   569.0
# 2  Ryoutsu, being an underpaid policeman, is alwa...  7.78  1074.0
# 3  Hunters are specialized in a wide variety of f...  8.42   188.0
# 4  Twenty-two-year-old Eikichi Onizuka—ex-biker g...  8.68    68.0
#
#    popularity  num_list_users  num_scoring_users  ...  \
# 0          17         2463199            1398717  ...
# 1        4962           21077               7777  ...
# 2        5063           20010               7396  ...
# 3         373          610441             297113  ...
# 4         218          857316             421043  ...
#
#                                            broadcast source  \
# 0  {'day_of_the_week': 'sunday', 'start_time': '0...  manga
# 1                                                NaN  novel
# 2  {'day_of_the_week': 'sunday', 'start_time': '1...  manga
# 3  {'day_of_the_week': 'saturday', 'start_time': ...  manga
# 4  {'day_of_the_week': 'wednesday', 'start_time':...  manga
#
#   average_episode_duration rating  \
# 0                     1440  pg_13
# 1                     1560      r
# 2                     1500  pg_13
# 3                     1380  pg_13
# 4                     1550      r
#
#                                           background  \
# 0  The anime had a hiatus from October 13, 2024 t...
# 1
# 2
# 3
# 4  First episode has a duration of 48 minutes, st...
#
#                                     studios  \
# 0    [{'id': 18, 'name': 'Toei Animation'}]
# 1       [{'id': 1269, 'name': 'K-Factory'}]
# 2            [{'id': 36, 'name': 'Gallop'}]
# 3  [{'id': 22, 'name': 'Nippon Animation'}]
# 4            [{'id': 1, 'name': 'Pierrot'}]
#
#                                           statistics  season  year    end_date
# 0  {'status': {'watching': '1746533', 'completed'...  winter  2000         NaN
# 1  {'status': {'watching': '983', 'completed': '9...  winter  2000  2000-07-21
# 2  {'status': {'watching': '1591', 'completed': '...  winter  2000  2004-12-19
# 3  {'status': {'watching': '44154', 'completed': ...  winter  2000  2001-03-31
# 4  {'status': {'watching': '71426', 'completed': ...  winter  2000  2000-09-17
#
# [5 rows x 28 columns]

# %%
pd.read_csv('dataset/anime.csv').nunique()
# Out:
# id                          5246
# title                       5245
# main_picture                5348
# start_date                  3136
# synopsis                    5097
# mean                         400
# rank                        4417
# popularity                  5204
# num_list_users              4587
# num_scoring_users           3905
# nsfw                           1
# created_at                  5246
# updated_at                  5243
# media_type                     9
# status                         2
# genres                      2186
# num_episodes                 152
# start_season                 115
# broadcast                    401
# source                        16
# average_episode_duration    1347
# rating                         5
# background                   939
# studios                      664
# statistics                  5267
# season                         4
# year                          24
# end_date                    3165
# dtype: int64

# %%
pd.read_csv('dataset/anime.csv').head()
# Out:
#      id                                             title  \
# 0    21                                         One Piece
# 1  3665                Ginga Eiyuu Densetsu Gaiden (1999)
# 2  3545  Kochira Katsushikaku Kameari Kouenmae Hashutsujo
# 3   136                                   Hunter x Hunter
# 4   245                             Great Teacher Onizuka
#
#                                         main_picture  start_date  \
# 0  {'medium': 'https://cdn.myanimelist.net/images...  1999-10-20
# 1  {'medium': 'https://cdn.myanimelist.net/images...  1999-12-24
# 2  {'medium': 'https://cdn.myanimelist.net/images...  1996-06-16
# 3  {'medium': 'https://cdn.myanimelist.net/images...  1999-10-16
# 4  {'medium': 'https://cdn.myanimelist.net/images...  1999-06-30
#
#                                             synopsis  mean    rank  \
# 0  Barely surviving in a barrel after passing thr...  8.72    54.0
# 1  Ginga Eiyuu Densetsu Gaiden (1999) is the seco...  8.06   569.0
# 2  Ryoutsu, being an underpaid policeman, is alwa...  7.78  1074.0
# 3  Hunters are specialized in a wide variety of f...  8.42   188.0
# 4  Twenty-two-year-old Eikichi Onizuka—ex-biker g...  8.68    68.0
#
#    popularity  num_list_users  num_scoring_users  ...  \
# 0          17         2463199            1398717  ...
# 1        4962           21077               7777  ...
# 2        5063           20010               7396  ...
# 3         373          610441             297113  ...
# 4         218          857316             421043  ...
#
#                                            broadcast source  \
# 0  {'day_of_the_week': 'sunday', 'start_time': '0...  manga
# 1                                                NaN  novel
# 2  {'day_of_the_week': 'sunday', 'start_time': '1...  manga
# 3  {'day_of_the_week': 'saturday', 'start_time': ...  manga
# 4  {'day_of_the_week': 'wednesday', 'start_time':...  manga
#
#   average_episode_duration rating  \
# 0                     1440  pg_13
# 1                     1560      r
# 2                     1500  pg_13
# 3                     1380  pg_13
# 4                     1550      r
#
#                                           background  \
# 0  The anime had a hiatus from October 13, 2024 t...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  First episode has a duration of 48 minutes, st...
#
#                                     studios  \
# 0    [{'id': 18, 'name': 'Toei Animation'}]
# 1       [{'id': 1269, 'name': 'K-Factory'}]
# 2            [{'id': 36, 'name': 'Gallop'}]
# 3  [{'id': 22, 'name': 'Nippon Animation'}]
# 4            [{'id': 1, 'name': 'Pierrot'}]
#
#                                           statistics  season  year    end_date
# 0  {'status': {'watching': '1746533', 'completed'...  winter  2000         NaN
# 1  {'status': {'watching': '983', 'completed': '9...  winter  2000  2000-07-21
# 2  {'status': {'watching': '1591', 'completed': '...  winter  2000  2004-12-19
# 3  {'status': {'watching': '44154', 'completed': ...  winter  2000  2001-03-31
# 4  {'status': {'watching': '71426', 'completed': ...  winter  2000  2000-09-17
#
# [5 rows x 28 columns]

# %%
df = pd.read_csv('dataset/rankings/ranking_airing.csv')
df.head()
# Out:
#       id                                             title  \
# 0  56784           Bleach: Sennen Kessen-hen - Soukoku-tan
# 1  54857  Re:Zero kara Hajimeru Isekai Seikatsu 3rd Season
# 2     21                                         One Piece
# 3  57334                                          Dandadan
# 4  55823                         Natsume Yuujinchou Shichi
#
#                                         main_picture  start_date  \
# 0  {'medium': 'https://cdn.myanimelist.net/images...  2024-10-05
# 1  {'medium': 'https://cdn.myanimelist.net/images...  2024-10-02
# 2  {'medium': 'https://cdn.myanimelist.net/images...  1999-10-20
# 3  {'medium': 'https://cdn.myanimelist.net/images...  2024-10-04
# 4  {'medium': 'https://cdn.myanimelist.net/images...  2024-10-08
#
#                                             synopsis  mean  rank  popularity  \
# 0  After an awe-inspiring battle with Ichibei Hyo...  8.98  14.0        1437
# 1  One year after the events at the Sanctuary, Su...  8.78  36.0         803
# 2  Barely surviving in a barrel after passing thr...  8.73  54.0          17
# 3  Reeling from her recent breakup, Momo Ayase, a...  8.70  64.0         497
# 4  As a young child, Takashi Natsume believed his...  8.67  70.0        3831
#
#    num_list_users  num_scoring_users  ...                      start_season  \
# 0          172693              36381  ...  {'year': 2024, 'season': 'fall'}
# 1          316202              48683  ...  {'year': 2024, 'season': 'fall'}
# 2         2463166            1398702  ...  {'year': 1999, 'season': 'fall'}
# 3          474981             120385  ...  {'year': 2024, 'season': 'fall'}
# 4           37211               3565  ...  {'year': 2024, 'season': 'fall'}
#
#                                            broadcast       source  \
# 0  {'day_of_the_week': 'saturday', 'start_time': ...        manga
# 1  {'day_of_the_week': 'wednesday', 'start_time':...  light_novel
# 2  {'day_of_the_week': 'sunday', 'start_time': '0...        manga
# 3  {'day_of_the_week': 'friday', 'start_time': '0...        manga
# 4  {'day_of_the_week': 'tuesday', 'start_time': '...        manga
#
#   average_episode_duration rating  \
# 0                     1478      r
# 1                     1420      r
# 2                     1440  pg_13
# 3                     1437      r
# 4                     1429  pg_13
#
#                                           background  \
# 0                                                NaN
# 1  Re:Zero kara Hajimeru Isekai Seikatsu 3rd Seas...
# 2  The anime had a hiatus from October 13, 2024 t...
# 3  Dandadan aired on MBS and TBS' Super Animeism ...
# 4                                                NaN
#
#                                    studios  \
# 0  [{'id': 2951, 'name': 'Pierrot Films'}]
# 1       [{'id': 314, 'name': 'White Fox'}]
# 2   [{'id': 18, 'name': 'Toei Animation'}]
# 3   [{'id': 1591, 'name': 'Science SARU'}]
# 4          [{'id': 1119, 'name': 'Shuka'}]
#
#                                           statistics airing_ranking  \
# 0  {'status': {'watching': '104509', 'completed':...              1
# 1  {'status': {'watching': '150997', 'completed':...              2
# 2  {'status': {'watching': '1746523', 'completed'...              3
# 3  {'status': {'watching': '358412', 'completed':...              4
# 4  {'status': {'watching': '12633', 'completed': ...              5
#
#      end_date
# 0         NaN
# 1         NaN
# 2         NaN
# 3  2024-12-20
# 4  2024-12-24
#
# [5 rows x 27 columns]
